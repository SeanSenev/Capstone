# %% [markdown]
# # part1 up to feature selection -------------->

# %%
# #mount files to googledirve
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !ls '/content/drive/My Drive/'

# %%
import pandas as pd

df = pd.read_csv('../Data/Flight Summary - North Atlantic - 2019.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
df.head()
# Out:
#   ICAO Aircraft type designator First known waypoint time (UTC)  \
# 0                          B772             2019-01-01 02:17:49
# 1                          B763             2019-01-01 02:19:06
# 2                          B763             2019-01-01 02:21:40
# 3                          B744             2019-01-01 02:16:31
# 4                          B789             2019-01-01 03:15:00
#
#   Last known waypoint time (UTC) Direction  Total flight dist (km)  \
# 0            2019-01-01 05:18:26         E             2633.994219
# 1            2019-01-01 05:27:55         E             2670.997754
# 2            2019-01-01 05:11:34         E             2388.740516
# 3            2019-01-01 05:44:38         E             3039.310160
# 4            2019-01-01 04:30:15         E             1092.545055
#
#    Total fuel burn (kg)  Mean overall propulsion efficiency  \
# 0          23991.530999                            0.311201
# 1          13886.660380                            0.325782
# 2          13397.610853                            0.304915
# 3          38210.558395                            0.317271
# 4           9686.423444                            0.282729
#
#    Aircraft mass mean (kg)  Mean nvPM number EI (kg-1)  \
# 0            228553.082349                4.920940e+14
# 1            150812.984413                1.425808e+15
# 2            150872.338643                1.172578e+15
# 3            311350.241271                5.589923e+14
# 4            212017.428561                8.404441e+14
#
#    Initial contrail length (km) First contrail waypoint time (UTC)  \
# 0                   1415.515126                                NaN
# 1                   1701.125144                2019-01-01 03:57:00
# 2                   2388.740516                                NaN
# 3                   2216.876721                                NaN
# 4                   1092.545055                                NaN
#
#   Last contrail waypoint time (UTC)  RHi initial, Mean  RHi initial, Stdev  \
# 0                               NaN           0.000000            0.000000
# 1               2019-01-01 05:27:55           1.079427            0.095837
# 2                               NaN           0.000000            0.000000
# 3                               NaN           0.000000            0.000000
# 4                               NaN           0.000000            0.000000
#
#    RHi lifetime, Mean  Temp initial, Mean (K)  Temp initial, Stdev (K)  \
# 0            0.000000                0.000000                 0.000000
# 1            1.090244              213.532187                 0.195622
# 2            0.000000                0.000000                 0.000000
# 3            0.000000                0.000000                 0.000000
# 4            0.000000                0.000000                 0.000000
#
#    Temp SAC, Mean (K)  Temp SAC, Stdev (K)  Persistent contrail length (km)  \
# 0            0.000000             0.000000                         0.000000
# 1          224.165862             0.689557                       536.746493
# 2            0.000000             0.000000                         0.000000
# 3            0.000000             0.000000                         0.000000
# 4            0.000000             0.000000                         0.000000
#
#    Contrail altitude initial, Mean (ft)  \
# 0                                   0.0
# 1                               35000.0
# 2                                   0.0
# 3                                   0.0
# 4                                   0.0
#
#    Contrail altitude lifetime, Mean (ft)  Contrail age, Mean (h)  \
# 0                               0.000000                0.000000
# 1                           34730.969825                4.587508
# 2                               0.000000                0.000000
# 3                               0.000000                0.000000
# 4                               0.000000                0.000000
#
#    Contrail age, Max (h)  Ice number initial, Mean (m-1)  \
# 0               0.000000                    0.000000e+00
# 1               9.044444                    3.968575e+12
# 2               0.000000                    0.000000e+00
# 3               0.000000                    0.000000e+00
# 4               0.000000                    0.000000e+00
#
#    Ice number initial, Stdev (m-1)  Ice number lifetime, Mean (m-1)  \
# 0                     0.000000e+00                     0.000000e+00
# 1                     1.091993e+12                     3.152803e+12
# 2                     0.000000e+00                     0.000000e+00
# 3                     0.000000e+00                     0.000000e+00
# 4                     0.000000e+00                     0.000000e+00
#
#    Ice vol mean radius, Mean (um)  Tau contrail, Mean  Tau cirrus, Mean  \
# 0                        0.000000            0.000000          0.000000
# 1                        3.716948            0.090483          0.001725
# 2                        0.000000            0.000000          0.000000
# 3                        0.000000            0.000000          0.000000
# 4                        0.000000            0.000000          0.000000
#
#    RF SW (W m-2)  RF LW (W m-2)  RF Net (W m-2)  Total contrail EF (J)  \
# 0       0.000000       0.000000        0.000000           0.000000e+00
# 1      -0.565425       4.231059        3.665634           1.515245e+14
# 2       0.000000       0.000000        0.000000           0.000000e+00
# 3       0.000000       0.000000        0.000000           0.000000e+00
# 4       0.000000       0.000000        0.000000           0.000000e+00
#
#    SDR mean (W m-2)  RSR mean (W m-2)  OLR mean (W m-2)
# 0          0.000000          0.000000          0.000000
# 1         36.862724         15.583469        238.200396
# 2          0.000000          0.000000          0.000000
# 3          0.000000          0.000000          0.000000
# 4          0.000000          0.000000          0.000000

# %%
df.shape
# Out:
# (477923, 37)

# %%
filtered_df_init = df[df["Initial contrail length (km)"] > 0]
print(filtered_df_init.shape)
filtered_df_init.head()
# Out:
# (435570, 37)
#   ICAO Aircraft type designator First known waypoint time (UTC)  \
# 0                          B772             2019-01-01 02:17:49
# 1                          B763             2019-01-01 02:19:06
# 2                          B763             2019-01-01 02:21:40
# 3                          B744             2019-01-01 02:16:31
# 4                          B789             2019-01-01 03:15:00
#
#   Last known waypoint time (UTC) Direction  Total flight dist (km)  \
# 0            2019-01-01 05:18:26         E             2633.994219
# 1            2019-01-01 05:27:55         E             2670.997754
# 2            2019-01-01 05:11:34         E             2388.740516
# 3            2019-01-01 05:44:38         E             3039.310160
# 4            2019-01-01 04:30:15         E             1092.545055
#
#    Total fuel burn (kg)  Mean overall propulsion efficiency  \
# 0          23991.530999                            0.311201
# 1          13886.660380                            0.325782
# 2          13397.610853                            0.304915
# 3          38210.558395                            0.317271
# 4           9686.423444                            0.282729
#
#    Aircraft mass mean (kg)  Mean nvPM number EI (kg-1)  \
# 0            228553.082349                4.920940e+14
# 1            150812.984413                1.425808e+15
# 2            150872.338643                1.172578e+15
# 3            311350.241271                5.589923e+14
# 4            212017.428561                8.404441e+14
#
#    Initial contrail length (km) First contrail waypoint time (UTC)  \
# 0                   1415.515126                                NaN
# 1                   1701.125144                2019-01-01 03:57:00
# 2                   2388.740516                                NaN
# 3                   2216.876721                                NaN
# 4                   1092.545055                                NaN
#
#   Last contrail waypoint time (UTC)  RHi initial, Mean  RHi initial, Stdev  \
# 0                               NaN           0.000000            0.000000
# 1               2019-01-01 05:27:55           1.079427            0.095837
# 2                               NaN           0.000000            0.000000
# 3                               NaN           0.000000            0.000000
# 4                               NaN           0.000000            0.000000
#
#    RHi lifetime, Mean  Temp initial, Mean (K)  Temp initial, Stdev (K)  \
# 0            0.000000                0.000000                 0.000000
# 1            1.090244              213.532187                 0.195622
# 2            0.000000                0.000000                 0.000000
# 3            0.000000                0.000000                 0.000000
# 4            0.000000                0.000000                 0.000000
#
#    Temp SAC, Mean (K)  Temp SAC, Stdev (K)  Persistent contrail length (km)  \
# 0            0.000000             0.000000                         0.000000
# 1          224.165862             0.689557                       536.746493
# 2            0.000000             0.000000                         0.000000
# 3            0.000000             0.000000                         0.000000
# 4            0.000000             0.000000                         0.000000
#
#    Contrail altitude initial, Mean (ft)  \
# 0                                   0.0
# 1                               35000.0
# 2                                   0.0
# 3                                   0.0
# 4                                   0.0
#
#    Contrail altitude lifetime, Mean (ft)  Contrail age, Mean (h)  \
# 0                               0.000000                0.000000
# 1                           34730.969825                4.587508
# 2                               0.000000                0.000000
# 3                               0.000000                0.000000
# 4                               0.000000                0.000000
#
#    Contrail age, Max (h)  Ice number initial, Mean (m-1)  \
# 0               0.000000                    0.000000e+00
# 1               9.044444                    3.968575e+12
# 2               0.000000                    0.000000e+00
# 3               0.000000                    0.000000e+00
# 4               0.000000                    0.000000e+00
#
#    Ice number initial, Stdev (m-1)  Ice number lifetime, Mean (m-1)  \
# 0                     0.000000e+00                     0.000000e+00
# 1                     1.091993e+12                     3.152803e+12
# 2                     0.000000e+00                     0.000000e+00
# 3                     0.000000e+00                     0.000000e+00
# 4                     0.000000e+00                     0.000000e+00
#
#    Ice vol mean radius, Mean (um)  Tau contrail, Mean  Tau cirrus, Mean  \
# 0                        0.000000            0.000000          0.000000
# 1                        3.716948            0.090483          0.001725
# 2                        0.000000            0.000000          0.000000
# 3                        0.000000            0.000000          0.000000
# 4                        0.000000            0.000000          0.000000
#
#    RF SW (W m-2)  RF LW (W m-2)  RF Net (W m-2)  Total contrail EF (J)  \
# 0       0.000000       0.000000        0.000000           0.000000e+00
# 1      -0.565425       4.231059        3.665634           1.515245e+14
# 2       0.000000       0.000000        0.000000           0.000000e+00
# 3       0.000000       0.000000        0.000000           0.000000e+00
# 4       0.000000       0.000000        0.000000           0.000000e+00
#
#    SDR mean (W m-2)  RSR mean (W m-2)  OLR mean (W m-2)
# 0          0.000000          0.000000          0.000000
# 1         36.862724         15.583469        238.200396
# 2          0.000000          0.000000          0.000000
# 3          0.000000          0.000000          0.000000
# 4          0.000000          0.000000          0.000000

# %%
filtered_df = df[df["Persistent contrail length (km)"] > 0]
print(filtered_df.shape)
filtered_df.head()
# Out:
# (267076, 37)
#    ICAO Aircraft type designator First known waypoint time (UTC)  \
# 1                           B763             2019-01-01 02:19:06
# 6                           B77W             2019-01-01 02:52:15
# 10                          B772             2019-01-01 00:16:39
# 21                          B789             2019-01-01 00:37:15
# 26                          B77W             2019-01-01 02:35:19
#
#    Last known waypoint time (UTC) Direction  Total flight dist (km)  \
# 1             2019-01-01 05:27:55         E             2670.997754
# 6             2019-01-01 05:40:58         W             2454.206073
# 10            2019-01-01 03:07:07         E             2565.932833
# 21            2019-01-01 03:13:24         E             2373.790808
# 26            2019-01-01 05:20:28         E             2510.123492
#
#     Total fuel burn (kg)  Mean overall propulsion efficiency  \
# 1           13886.660380                            0.325782
# 6           22961.400338                            0.349929
# 10          19625.791058                            0.336568
# 21          13802.532168                            0.366840
# 26          23168.670110                            0.344524
#
#     Aircraft mass mean (kg)  Mean nvPM number EI (kg-1)  \
# 1             150812.984413                1.425808e+15
# 6             284846.653436                5.387187e+14
# 10            231552.546423                5.180514e+14
# 21            210022.578846                1.302981e+15
# 26            284705.962602                5.273441e+14
#
#     Initial contrail length (km) First contrail waypoint time (UTC)  \
# 1                    1701.125144                2019-01-01 03:57:00
# 6                    2301.760372                2019-01-01 03:21:55
# 10                   1769.517466                2019-01-01 01:42:00
# 21                   1928.436442                2019-01-01 01:50:00
# 26                   1766.966954                2019-01-01 03:54:00
#
#    Last contrail waypoint time (UTC)  RHi initial, Mean  RHi initial, Stdev  \
# 1                2019-01-01 05:27:55           1.079427            0.095837
# 6                2019-01-01 04:37:05           1.126386            0.099660
# 10               2019-01-01 03:00:31           1.025785            0.116090
# 21               2019-01-01 03:06:12           1.043189            0.185355
# 26               2019-01-01 05:18:20           1.206695            0.174838
#
#     RHi lifetime, Mean  Temp initial, Mean (K)  Temp initial, Stdev (K)  \
# 1             1.090244              213.532187                 0.195622
# 6             1.198398              219.280309                 0.123778
# 10            1.185167              213.109171                 0.357759
# 21            1.056863              209.719876                 0.454122
# 26            1.291640              216.649989                 0.165068
#
#     Temp SAC, Mean (K)  Temp SAC, Stdev (K)  Persistent contrail length (km)  \
# 1           224.165862             0.689557                       536.746493
# 6           226.628927             0.510421                       769.466861
# 10          224.495320             0.411562                      1138.698193
# 21          224.015861             0.687361                      1244.628185
# 26          226.470511             0.786973                      1209.709142
#
#     Contrail altitude initial, Mean (ft)  \
# 1                                35000.0
# 6                                32000.0
# 10                               35000.0
# 21                               37000.0
# 26                               33000.0
#
#     Contrail altitude lifetime, Mean (ft)  Contrail age, Mean (h)  \
# 1                            34730.969825                4.587508
# 6                            31783.306898                4.999370
# 10                           34903.261225                4.827353
# 21                           36926.815458                3.585061
# 26                           32676.594326                5.311598
#
#     Contrail age, Max (h)  Ice number initial, Mean (m-1)  \
# 1                9.044444                    3.968575e+12
# 6                7.056111                    2.635152e+12
# 10               7.233333                    2.279124e+12
# 21               5.325833                    5.974121e+12
# 26              10.866667                    3.175801e+12
#
#     Ice number initial, Stdev (m-1)  Ice number lifetime, Mean (m-1)  \
# 1                      1.091993e+12                     3.152803e+12
# 6                      1.256472e+12                     1.304154e+12
# 10                     9.900186e+11                     1.931566e+12
# 21                     7.981775e+11                     4.745950e+12
# 26                     1.288902e+12                     1.899367e+12
#
#     Ice vol mean radius, Mean (um)  Tau contrail, Mean  Tau cirrus, Mean  \
# 1                         3.716948            0.090483          0.001725
# 6                        14.000310            0.170856          0.167571
# 10                        9.268893            0.079008          0.045336
# 21                        2.969259            0.049081          0.042563
# 26                       13.593999            0.182512          0.186217
#
#     RF SW (W m-2)  RF LW (W m-2)  RF Net (W m-2)  Total contrail EF (J)  \
# 1       -0.565425       4.231059        3.665634           1.515245e+14
# 6        0.000000       8.847818        8.847818           9.437860e+14
# 10       0.000000       4.523805        4.523805           8.174670e+14
# 21       0.000000       1.678470        1.678470           2.105545e+14
# 26      -0.003279       9.024577        9.021298           1.350368e+15
#
#     SDR mean (W m-2)  RSR mean (W m-2)  OLR mean (W m-2)
# 1          36.862724         15.583469        238.200396
# 6           0.034721          0.055088        208.938358
# 10          0.000000          0.000000        216.175025
# 21          0.000000          0.000000        195.035091
# 26          0.645140          0.419577        200.392768

# %%
print(df.shape[0]-filtered_df.shape[0],(df.shape[0]-filtered_df.shape[0])/len(df))  #throwing off 210847 rows
# Out:
# 210847 0.4411735781705421

# %%
import matplotlib.pyplot as plt
numerical_features = filtered_df.select_dtypes(include=['float64', 'int64'])
numerical_features.hist(bins=50, figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot histograms for "Initial contrail length (km)", "Persistent contrail length (km)", and "Contrail age, Mean (h)"
fig, ax = plt.subplots(1, 3, figsize=(20, 5))

# Initial contrail length histogram
ax[0].hist(filtered_df["Initial contrail length (km)"], bins=30, color='blue', alpha=0.7)
ax[0].set_title("Initial Contrail Length Distribution")
ax[0].set_xlabel("Length (km)")
ax[0].set_ylabel("Frequency")

# Persistent contrail length histogram
ax[1].hist(filtered_df["Persistent contrail length (km)"], bins=30, color='green', alpha=0.7)
ax[1].set_title("Persistent Contrail Length Distribution")
ax[1].set_xlabel("Length (km)")
ax[1].set_ylabel("Frequency")

# Contrail age histogram
ax[2].hist(filtered_df["Contrail age, Mean (h)"], bins=30, color='orange', alpha=0.7)
ax[2].set_title("Contrail Age Distribution")
ax[2].set_xlabel("Age (hours)")
ax[2].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
#sanity check - NO persistent contrails forms wo formation of initial contrail
df[(df["Initial contrail length (km)"] <= 0) & (df["Persistent contrail length (km)"] > 0)]
# Out:
# Empty DataFrame
# Columns: [ICAO Aircraft type designator, First known waypoint time (UTC), Last known waypoint time (UTC), Direction, Total flight dist (km), Total fuel burn (kg), Mean overall propulsion efficiency, Aircraft mass mean (kg), Mean nvPM number EI (kg-1), Initial contrail length (km), First contrail waypoint time (UTC), Last contrail waypoint time (UTC), RHi initial, Mean, RHi initial, Stdev, RHi lifetime, Mean, Temp initial, Mean (K), Temp initial, Stdev (K), Temp SAC, Mean (K), Temp SAC, Stdev (K), Persistent contrail length (km), Contrail altitude initial, Mean (ft), Contrail altitude lifetime, Mean (ft), Contrail age, Mean (h), Contrail age, Max (h), Ice number initial, Mean (m-1), Ice number initial, Stdev (m-1), Ice number lifetime, Mean (m-1), Ice vol mean radius, Mean (um), Tau contrail, Mean, Tau cirrus, Mean, RF SW (W m-2), RF LW (W m-2), RF Net (W m-2), Total contrail EF (J), SDR mean (W m-2), RSR mean (W m-2), OLR mean (W m-2)]
# Index: []

# %%
#61% of inintial contrails also form persistent contrails
print(len(df[(df["Initial contrail length (km)"] > 0) & (df["Persistent contrail length (km)"] != 0)])/len(filtered_df))
df[(df["Initial contrail length (km)"] > 0) & (df["Persistent contrail length (km)"] != 0)]
# Out:
# 1.0
#        ICAO Aircraft type designator First known waypoint time (UTC)  \
# 1                               B763             2019-01-01 02:19:06
# 6                               B77W             2019-01-01 02:52:15
# 10                              B772             2019-01-01 00:16:39
# 21                              B789             2019-01-01 00:37:15
# 26                              B77W             2019-01-01 02:35:19
# ...                              ...                             ...
# 477918                          B763             2019-12-31 00:38:04
# 477919                          B748             2019-12-31 23:31:06
# 477920                          A333             2019-12-31 23:37:19
# 477921                          B77W             2019-12-31 23:40:59
# 477922                          A332             2019-12-31 23:54:31
#
#        Last known waypoint time (UTC) Direction  Total flight dist (km)  \
# 1                 2019-01-01 05:27:55         E             2670.997754
# 6                 2019-01-01 05:40:58         W             2454.206073
# 10                2019-01-01 03:07:07         E             2565.932833
# 21                2019-01-01 03:13:24         E             2373.790808
# 26                2019-01-01 05:20:28         E             2510.123492
# ...                               ...       ...                     ...
# 477918            2019-12-31 02:56:54         E             2087.017297
# 477919            2020-01-01 02:25:41         E             2606.391287
# 477920            2020-01-01 02:30:19         E             2548.921249
# 477921            2020-01-01 02:20:27         E             2459.847311
# 477922            2020-01-01 02:41:02         E             2445.331635
#
#         Total fuel burn (kg)  Mean overall propulsion efficiency  \
# 1               13886.660380                            0.325782
# 6               22961.400338                            0.349929
# 10              19625.791058                            0.336568
# 21              13802.532168                            0.366840
# 26              23168.670110                            0.344524
# ...                      ...                                 ...
# 477918          10207.228653                            0.321702
# 477919          28388.405476                            0.352150
# 477920          14514.808022                            0.314231
# 477921          22281.324954                            0.335076
# 477922          16302.729400                            0.295233
#
#         Aircraft mass mean (kg)  Mean nvPM number EI (kg-1)  \
# 1                 150812.984413                1.425808e+15
# 6                 284846.653436                5.387187e+14
# 10                231552.546423                5.180514e+14
# 21                210022.578846                1.302981e+15
# 26                284705.962602                5.273441e+14
# ...                         ...                         ...
# 477918            152685.927840                1.135276e+15
# 477919            358167.013695                2.394486e+14
# 477920            180359.996557                1.204005e+15
# 477921            287500.712647                5.132590e+14
# 477922            190553.163798                7.427883e+14
#
#         Initial contrail length (km) First contrail waypoint time (UTC)  \
# 1                        1701.125144                2019-01-01 03:57:00
# 6                        2301.760372                2019-01-01 03:21:55
# 10                       1769.517466                2019-01-01 01:42:00
# 21                       1928.436442                2019-01-01 01:50:00
# 26                       1766.966954                2019-01-01 03:54:00
# ...                              ...                                ...
# 477918                   2087.017297                2019-12-31 00:38:04
# 477919                   2606.391287                2019-12-31 23:31:06
# 477920                   2548.921249                2019-12-31 23:37:19
# 477921                   2459.847311                2019-12-31 23:40:59
# 477922                   2202.308302                2020-01-01 01:52:17
#
#        Last contrail waypoint time (UTC)  RHi initial, Mean  \
# 1                    2019-01-01 05:27:55           1.079427
# 6                    2019-01-01 04:37:05           1.126386
# 10                   2019-01-01 03:00:31           1.025785
# 21                   2019-01-01 03:06:12           1.043189
# 26                   2019-01-01 05:18:20           1.206695
# ...                                  ...                ...
# 477918               2019-12-31 01:53:00           1.090726
# 477919               2020-01-01 02:25:41           1.049879
# 477920               2020-01-01 02:30:19           0.937956
# 477921               2020-01-01 02:20:27           1.247898
# 477922               2020-01-01 02:41:02           0.772049
#
#         RHi initial, Stdev  RHi lifetime, Mean  Temp initial, Mean (K)  \
# 1                 0.095837            1.090244              213.532187
# 6                 0.099660            1.198398              219.280309
# 10                0.116090            1.185167              213.109171
# 21                0.185355            1.056863              209.719876
# 26                0.174838            1.291640              216.649989
# ...                    ...                 ...                     ...
# 477918            0.108395            1.116687              210.201732
# 477919            0.116941            1.076081              210.874679
# 477920            0.186327            1.044968              207.150386
# 477921            0.159853            1.190958              216.861311
# 477922            0.223757            1.135152              205.355716
#
#         Temp initial, Stdev (K)  Temp SAC, Mean (K)  Temp SAC, Stdev (K)  \
# 1                      0.195622          224.165862             0.689557
# 6                      0.123778          226.628927             0.510421
# 10                     0.357759          224.495320             0.411562
# 21                     0.454122          224.015861             0.687361
# 26                     0.165068          226.470511             0.786973
# ...                         ...                 ...                  ...
# 477918                 0.163783          223.415738             0.453072
# 477919                 1.240604          224.607408             0.607586
# 477920                 2.925644          222.211430             0.657275
# 477921                 1.565069          226.110146             1.010995
# 477922                 1.162411          220.220691             0.668201
#
#         Persistent contrail length (km)  Contrail altitude initial, Mean (ft)  \
# 1                            536.746493                          35000.000000
# 6                            769.466861                          32000.000000
# 10                          1138.698193                          35000.000000
# 21                          1244.628185                          37000.000000
# 26                          1209.709142                          33000.000000
# ...                                 ...                                   ...
# 477918                      1125.965753                          37000.000000
# 477919                       940.083535                          35000.000000
# 477920                       793.452416                          37724.137931
# 477921                      1086.641065                          33000.000000
# 477922                       767.414428                          41000.000000
#
#         Contrail altitude lifetime, Mean (ft)  Contrail age, Mean (h)  \
# 1                                34730.969825                4.587508
# 6                                31783.306898                4.999370
# 10                               34903.261225                4.827353
# 21                               36926.815458                3.585061
# 26                               32676.594326                5.311598
# ...                                       ...                     ...
# 477918                           37154.083442                8.579962
# 477919                           35441.620271                6.743272
# 477920                           38479.758343                7.383135
# 477921                           32780.863015                3.640488
# 477922                           40779.217652                5.266111
#
#         Contrail age, Max (h)  Ice number initial, Mean (m-1)  \
# 1                    9.044444                    3.968575e+12
# 6                    7.056111                    2.635152e+12
# 10                   7.233333                    2.279124e+12
# 21                   5.325833                    5.974121e+12
# 26                  10.866667                    3.175801e+12
# ...                       ...                             ...
# 477918              13.532222                    4.719248e+12
# 477919               9.582778                    1.755778e+12
# 477920               9.341667                    4.743076e+12
# 477921               7.556944                    3.611247e+12
# 477922               8.032778                    3.701280e+12
#
#         Ice number initial, Stdev (m-1)  Ice number lifetime, Mean (m-1)  \
# 1                          1.091993e+12                     3.152803e+12
# 6                          1.256472e+12                     1.304154e+12
# 10                         9.900186e+11                     1.931566e+12
# 21                         7.981775e+11                     4.745950e+12
# 26                         1.288902e+12                     1.899367e+12
# ...                                 ...                              ...
# 477918                     7.926230e+11                     3.184250e+12
# 477919                     4.786200e+11                     1.494661e+12
# 477920                     1.132900e+12                     3.600077e+12
# 477921                     1.079122e+12                     2.676856e+12
# 477922                     8.051785e+11                     3.079417e+12
#
#         Ice vol mean radius, Mean (um)  Tau contrail, Mean  Tau cirrus, Mean  \
# 1                             3.716948            0.090483          0.001725
# 6                            14.000310            0.170856          0.167571
# 10                            9.268893            0.079008          0.045336
# 21                            2.969259            0.049081          0.042563
# 26                           13.593999            0.182512          0.186217
# ...                                ...                 ...               ...
# 477918                        7.428535            0.081363          0.090032
# 477919                       10.035975            0.084320          0.177454
# 477920                        4.552373            0.048974          0.050680
# 477921                        8.937103            0.180665          0.155855
# 477922                        3.845166            0.035748          0.008831
#
#         RF SW (W m-2)  RF LW (W m-2)  RF Net (W m-2)  Total contrail EF (J)  \
# 1           -0.565425       4.231059        3.665634           1.515245e+14
# 6            0.000000       8.847818        8.847818           9.437860e+14
# 10           0.000000       4.523805        4.523805           8.174670e+14
# 21           0.000000       1.678470        1.678470           2.105545e+14
# 26          -0.003279       9.024577        9.021298           1.350368e+15
# ...               ...            ...             ...                    ...
# 477918      -0.137038       4.689946        4.552907           2.226959e+15
# 477919      -0.008752       3.328687        3.319935           5.025183e+14
# 477920      -0.063604       1.617656        1.554052           1.772225e+14
# 477921       0.000000       7.198659        7.198659           5.632022e+14
# 477922      -0.149001       2.100622        1.951621           7.796891e+13
#
#         SDR mean (W m-2)  RSR mean (W m-2)  OLR mean (W m-2)
# 1              36.862724         15.583469        238.200396
# 6               0.034721          0.055088        208.938358
# 10              0.000000          0.000000        216.175025
# 21              0.000000          0.000000        195.035091
# 26              0.645140          0.419577        200.392768
# ...                  ...               ...               ...
# 477918         20.154910          8.090933        219.566534
# 477919          2.267464          1.518795        166.905632
# 477920          5.126751          3.460691        157.205241
# 477921          0.000000          0.000000        195.630176
# 477922          7.555699          2.399325        218.196422
#
# [267076 rows x 37 columns]

# %%
min(filtered_df["Initial contrail length (km)"])
# Out:
# 11.715237727805754

# %%
min(filtered_df["Persistent contrail length (km)"])
# Out:
# 7.54252333085259

# %%
filtered_df.columns
# Out:
# Index(['ICAO Aircraft type designator', 'First known waypoint time (UTC)',
#        'Last known waypoint time (UTC)', 'Direction', 'Total flight dist (km)',
#        'Total fuel burn (kg)', 'Mean overall propulsion efficiency',
#        'Aircraft mass mean (kg)', 'Mean nvPM number EI (kg-1)',
#        'Initial contrail length (km)', 'First contrail waypoint time (UTC)',
#        'Last contrail waypoint time (UTC)', 'RHi initial, Mean',
#        'RHi initial, Stdev', 'RHi lifetime, Mean', 'Temp initial, Mean (K)',
#        'Temp initial, Stdev (K)', 'Temp SAC, Mean (K)', 'Temp SAC, Stdev (K)',
#        'Persistent contrail length (km)',
#        'Contrail altitude initial, Mean (ft)',
#        'Contrail altitude lifetime, Mean (ft)', 'Contrail age, Mean (h)',
#        'Contrail age, Max (h)', 'Ice number initial, Mean (m-1)',
#        'Ice number initial, Stdev (m-1)', 'Ice number lifetime, Mean (m-1)',
#        'Ice vol mean radius, Mean (um)', 'Tau contrail, Mean',
#        'Tau cirrus, Mean', 'RF SW (W m-2)', 'RF LW (W m-2)', 'RF Net (W m-2)',
#        'Total contrail EF (J)', 'SDR mean (W m-2)', 'RSR mean (W m-2)',
#        'OLR mean (W m-2)'],
#       dtype='object')

# %%
exclude_cols = ['First known waypoint time (UTC)',
                'Last known waypoint time (UTC)',
                'First contrail waypoint time (UTC)',
                'Last contrail waypoint time (UTC)',
                'RHi initial, Stdev',
                'RHi lifetime, Mean',
                'Temp initial, Stdev (K)',
                'Temp SAC, Stdev (K)',
                'Ice number initial, Stdev (m-1)',
                'Ice number lifetime, Mean (m-1)',
                'Contrail altitude lifetime, Mean (ft)',
                'Contrail age, Max (h)',
                'ICAO Aircraft type designator',
                'Direction',
                'Initial contrail length (km)'
]  
        #excl timestamps
        #aircraft type/direction - categorical 
        #std/max/lifetime - measurements of period
        #initial contrail measures
modeling_df2 = filtered_df.drop(columns = exclude_cols)
modeling_df2
# Out:
#         Total flight dist (km)  Total fuel burn (kg)  \
# 1                  2670.997754          13886.660380
# 6                  2454.206073          22961.400338
# 10                 2565.932833          19625.791058
# 21                 2373.790808          13802.532168
# 26                 2510.123492          23168.670110
# ...                        ...                   ...
# 477918             2087.017297          10207.228653
# 477919             2606.391287          28388.405476
# 477920             2548.921249          14514.808022
# 477921             2459.847311          22281.324954
# 477922             2445.331635          16302.729400
#
#         Mean overall propulsion efficiency  Aircraft mass mean (kg)  \
# 1                                 0.325782            150812.984413
# 6                                 0.349929            284846.653436
# 10                                0.336568            231552.546423
# 21                                0.366840            210022.578846
# 26                                0.344524            284705.962602
# ...                                    ...                      ...
# 477918                            0.321702            152685.927840
# 477919                            0.352150            358167.013695
# 477920                            0.314231            180359.996557
# 477921                            0.335076            287500.712647
# 477922                            0.295233            190553.163798
#
#         Mean nvPM number EI (kg-1)  RHi initial, Mean  Temp initial, Mean (K)  \
# 1                     1.425808e+15           1.079427              213.532187
# 6                     5.387187e+14           1.126386              219.280309
# 10                    5.180514e+14           1.025785              213.109171
# 21                    1.302981e+15           1.043189              209.719876
# 26                    5.273441e+14           1.206695              216.649989
# ...                            ...                ...                     ...
# 477918                1.135276e+15           1.090726              210.201732
# 477919                2.394486e+14           1.049879              210.874679
# 477920                1.204005e+15           0.937956              207.150386
# 477921                5.132590e+14           1.247898              216.861311
# 477922                7.427883e+14           0.772049              205.355716
#
#         Temp SAC, Mean (K)  Persistent contrail length (km)  \
# 1               224.165862                       536.746493
# 6               226.628927                       769.466861
# 10              224.495320                      1138.698193
# 21              224.015861                      1244.628185
# 26              226.470511                      1209.709142
# ...                    ...                              ...
# 477918          223.415738                      1125.965753
# 477919          224.607408                       940.083535
# 477920          222.211430                       793.452416
# 477921          226.110146                      1086.641065
# 477922          220.220691                       767.414428
#
#         Contrail altitude initial, Mean (ft)  Contrail age, Mean (h)  \
# 1                               35000.000000                4.587508
# 6                               32000.000000                4.999370
# 10                              35000.000000                4.827353
# 21                              37000.000000                3.585061
# 26                              33000.000000                5.311598
# ...                                      ...                     ...
# 477918                          37000.000000                8.579962
# 477919                          35000.000000                6.743272
# 477920                          37724.137931                7.383135
# 477921                          33000.000000                3.640488
# 477922                          41000.000000                5.266111
#
#         Ice number initial, Mean (m-1)  Ice vol mean radius, Mean (um)  \
# 1                         3.968575e+12                        3.716948
# 6                         2.635152e+12                       14.000310
# 10                        2.279124e+12                        9.268893
# 21                        5.974121e+12                        2.969259
# 26                        3.175801e+12                       13.593999
# ...                                ...                             ...
# 477918                    4.719248e+12                        7.428535
# 477919                    1.755778e+12                       10.035975
# 477920                    4.743076e+12                        4.552373
# 477921                    3.611247e+12                        8.937103
# 477922                    3.701280e+12                        3.845166
#
#         Tau contrail, Mean  Tau cirrus, Mean  RF SW (W m-2)  RF LW (W m-2)  \
# 1                 0.090483          0.001725      -0.565425       4.231059
# 6                 0.170856          0.167571       0.000000       8.847818
# 10                0.079008          0.045336       0.000000       4.523805
# 21                0.049081          0.042563       0.000000       1.678470
# 26                0.182512          0.186217      -0.003279       9.024577
# ...                    ...               ...            ...            ...
# 477918            0.081363          0.090032      -0.137038       4.689946
# 477919            0.084320          0.177454      -0.008752       3.328687
# 477920            0.048974          0.050680      -0.063604       1.617656
# 477921            0.180665          0.155855       0.000000       7.198659
# 477922            0.035748          0.008831      -0.149001       2.100622
#
#         RF Net (W m-2)  Total contrail EF (J)  SDR mean (W m-2)  \
# 1             3.665634           1.515245e+14         36.862724
# 6             8.847818           9.437860e+14          0.034721
# 10            4.523805           8.174670e+14          0.000000
# 21            1.678470           2.105545e+14          0.000000
# 26            9.021298           1.350368e+15          0.645140
# ...                ...                    ...               ...
# 477918        4.552907           2.226959e+15         20.154910
# 477919        3.319935           5.025183e+14          2.267464
# 477920        1.554052           1.772225e+14          5.126751
# 477921        7.198659           5.632022e+14          0.000000
# 477922        1.951621           7.796891e+13          7.555699
#
#         RSR mean (W m-2)  OLR mean (W m-2)
# 1              15.583469        238.200396
# 6               0.055088        208.938358
# 10              0.000000        216.175025
# 21              0.000000        195.035091
# 26              0.419577        200.392768
# ...                  ...               ...
# 477918          8.090933        219.566534
# 477919          1.518795        166.905632
# 477920          3.460691        157.205241
# 477921          0.000000        195.630176
# 477922          2.399325        218.196422
#
# [267076 rows x 22 columns]

# %%
modeling_df2.columns
# Out:
# Index(['Total flight dist (km)', 'Total fuel burn (kg)',
#        'Mean overall propulsion efficiency', 'Aircraft mass mean (kg)',
#        'Mean nvPM number EI (kg-1)', 'RHi initial, Mean',
#        'Temp initial, Mean (K)', 'Temp SAC, Mean (K)',
#        'Persistent contrail length (km)',
#        'Contrail altitude initial, Mean (ft)', 'Contrail age, Mean (h)',
#        'Ice number initial, Mean (m-1)', 'Ice vol mean radius, Mean (um)',
#        'Tau contrail, Mean', 'Tau cirrus, Mean', 'RF SW (W m-2)',
#        'RF LW (W m-2)', 'RF Net (W m-2)', 'Total contrail EF (J)',
#        'SDR mean (W m-2)', 'RSR mean (W m-2)', 'OLR mean (W m-2)'],
#       dtype='object')

# %%
print(modeling_df2.isnull().sum())  #no NA
# Out:
# Total flight dist (km)                  0
# Total fuel burn (kg)                    0
# Mean overall propulsion efficiency      0
# Aircraft mass mean (kg)                 0
# Mean nvPM number EI (kg-1)              0
# RHi initial, Mean                       0
# Temp initial, Mean (K)                  0
# Temp SAC, Mean (K)                      0
# Persistent contrail length (km)         0
# Contrail altitude initial, Mean (ft)    0
# Contrail age, Mean (h)                  0
# Ice number initial, Mean (m-1)          0
# Ice vol mean radius, Mean (um)          0
# Tau contrail, Mean                      0
# Tau cirrus, Mean                        0
# RF SW (W m-2)                           0
# RF LW (W m-2)                           0
# RF Net (W m-2)                          0
# Total contrail EF (J)                   0
# SDR mean (W m-2)                        0
# RSR mean (W m-2)                        0
# OLR mean (W m-2)                        0
# dtype: int64

# %% [markdown]
# # split data & feature selection

# %%
#define X & y 

modeling_df2 = modeling_df2.sample(frac=1, random_state=42).reset_index(drop=True)  #shuffle data

X = modeling_df2.drop(columns=["Persistent contrail length (km)", "Contrail age, Mean (h)"])
y1 = modeling_df2["Persistent contrail length (km)"]
y2 = modeling_df2["Contrail age, Mean (h)"]

# %%
#split into train vs val vs test as 8:1:1

from sklearn.model_selection import train_test_split
#train:test as 8:2
X_train, X_temp, y1_train, y1_temp, y2_train, y2_temp = train_test_split(
    X, y1, y2, test_size=0.2, random_state=42)

#val:test as 1:1
X_val, X_test, y1_val, y1_test, y2_val, y2_test = train_test_split(
    X_temp, y1_temp, y2_temp, test_size=0.5, random_state=42)  # random_state can be different or same

X_train.shape, X_val.shape, X_test.shape
# Out:
# ((213660, 20), (26708, 20), (26708, 20))

# %%
#feature selections using randomforest - takes 30mins!!!
from sklearn.ensemble import RandomForestRegressor
rf_selector = RandomForestRegressor()  #takes 30mins!!!
rf_selector.fit(X_train, y2_train)   #using y2 as target ie contrail age

important_features = rf_selector.feature_importances_
top_10_indices = important_features.argsort()[-10:][::-1]

#X input for RF
X_train_selected = X_train.iloc[:, top_10_indices]
X_val_selected = X_val.iloc[:, top_10_indices]
X_test_selected = X_test.iloc[:, top_10_indices]

# %%
#top 10 features based on RandomForestRegressor
top_features = X_train.columns[top_10_indices]
top_features
# Out:
# Index(['Ice vol mean radius, Mean (um)', 'Total contrail EF (J)',
#        'Temp initial, Mean (K)', 'Tau cirrus, Mean',
#        'Ice number initial, Mean (m-1)', 'RF LW (W m-2)', 'RF SW (W m-2)',
#        'RHi initial, Mean', 'Mean nvPM number EI (kg-1)',
#        'Tau contrail, Mean'],
#       dtype='object')

# %% [markdown]
# #### predictor_columns = correlations.nlargest(11).index.values
# #### predictor_columns
# array(['Persistent contrail length (km)', 'RHi initial, Stdev',
#        'Temp SAC, Mean (K)', 'Temp initial, Mean (K)',
#        'RHi initial, Mean', 'OLR mean (W m-2)', 'Temp initial, Stdev (K)',
#        'Temp SAC, Stdev (K)', 'Ice number initial, Mean (m-1)',
#        'Ice number initial, Stdev (m-1)',
#        'Ice vol mean radius, Mean (um)'], dtype=object)

# %%
#save train_data
train_data = pd.concat([X_train_selected, y1_train.rename('y1_train'), y2_train.rename('y2_train')], axis=1)
train_data.to_csv('train_data.csv', index=False)

#save val_data
val_data = pd.concat([X_val_selected, y1_val.rename('y1_val'), y2_val.rename('y2_val')], axis=1)
val_data.to_csv('val_data.csv', index=False)

#save test_data
test_data = pd.concat([X_test_selected, y1_test.rename('y1_test'), y2_test.rename('y2_test')], axis=1)
test_data.to_csv('test_data.csv', index=False)

# %%
train_data
# Out:
#         Ice vol mean radius, Mean (um)  Total contrail EF (J)  \
# 79501                         8.104943          -9.803122e+13
# 118322                       11.396851           6.526151e+14
# 15500                         1.174947          -6.665474e+11
# 213654                        5.127562           6.506736e+13
# 260126                       14.515607           1.870152e+13
# ...                                ...                    ...
# 119879                        6.287990          -5.848262e+13
# 259178                       13.782106           2.838121e+14
# 131932                        6.192778           4.031556e+14
# 146867                        0.448273           0.000000e+00
# 121958                        3.908410           5.705916e+15
#
#         Temp initial, Mean (K)  Tau cirrus, Mean  \
# 79501               211.988027          0.059461
# 118322              214.539888          0.230156
# 15500               206.463294          0.017427
# 213654              210.716904          0.024615
# 260126              223.596470          0.348228
# ...                        ...               ...
# 119879              205.665296          0.037373
# 259178              220.456859          0.151028
# 131932              208.486587          0.128156
# 146867              215.152319          0.000000
# 121958              209.313214          0.015893
#
#         Ice number initial, Mean (m-1)  RF LW (W m-2)  RF SW (W m-2)  \
# 79501                     8.171083e+11       1.274654      -2.136018
# 118322                    4.825063e+12       2.709673      -0.462785
# 15500                     4.640423e+12       0.447756      -0.318402
# 213654                    2.980002e+12       1.514753      -1.687507
# 260126                    3.710018e+12       4.307649      -2.705854
# ...                                ...            ...            ...
# 119879                    4.442903e+12       3.004852      -3.928538
# 259178                    2.869579e+12       9.203848      -4.468458
# 131932                    4.726921e+12       2.685974      -1.603496
# 146867                    2.826432e+12       0.879319      -7.044063
# 121958                    1.590598e+13       3.786673      -4.405123
#
#         RHi initial, Mean  Mean nvPM number EI (kg-1)  Tau contrail, Mean  \
# 79501            0.965391                9.737014e+14            0.032228
# 118322           1.077596                1.409608e+15            0.086032
# 15500            0.934291                1.517921e+15            0.045242
# 213654           1.118627                5.143456e+14            0.046715
# 260126           1.201717                5.576476e+14            0.222517
# ...                   ...                         ...                 ...
# 119879           1.026555                3.800872e+14            0.035124
# 259178           1.199525                5.534915e+14            0.267492
# 131932           1.024720                1.132473e+15            0.066817
# 146867           0.865739                1.249643e+15            0.081751
# 121958           1.138260                1.314814e+15            0.104176
#
#            y1_train  y2_train
# 79501   1733.235630  4.177707
# 118322   453.631290  5.283710
# 15500    437.690005  1.973889
# 213654   471.390352  4.040959
# 260126   252.803424  4.584524
# ...             ...       ...
# 119879  1222.756573  3.638854
# 259178   699.814017  5.102403
# 131932  1527.142264  5.110816
# 146867   159.758003  0.008611
# 121958  2483.660064  6.087565
#
# [213660 rows x 12 columns]

# %%
val_data
# Out:
#         Ice vol mean radius, Mean (um)  Total contrail EF (J)  \
# 22481                         0.621634           0.000000e+00
# 25986                         8.295259          -1.405463e+14
# 81343                        10.575963           4.345377e+14
# 16215                         7.506634           1.992671e+14
# 2306                          2.408187          -5.699261e+13
# ...                                ...                    ...
# 180743                        0.462285           1.847574e+08
# 44251                         3.115405           1.304669e+14
# 93551                         4.049940           9.679952e+13
# 25427                         3.980783          -2.287857e+11
# 70609                         4.543444          -3.913506e+13
#
#         Temp initial, Mean (K)  Tau cirrus, Mean  \
# 22481               214.234077          0.083737
# 25986               220.717627          0.217203
# 81343               219.513314          0.119738
# 16215               219.258717          0.049590
# 2306                214.575615          0.001721
# ...                        ...               ...
# 180743              216.085266          0.000021
# 44251               207.313698          0.057284
# 93551               218.217409          0.056536
# 25427               220.669628          0.031450
# 70609               220.608097          0.118600
#
#         Ice number initial, Mean (m-1)  RF LW (W m-2)  RF SW (W m-2)  \
# 22481                     2.607814e+12       0.804535       0.000000
# 25986                     2.585102e+12       6.046565      -7.174444
# 81343                     5.151995e+12       9.101111      -1.225353
# 16215                     3.490247e+12       6.293696      -3.582462
# 2306                      3.876507e+12       6.221419     -13.302913
# ...                                ...            ...            ...
# 180743                    5.449088e+12       1.117746      -0.036764
# 44251                     4.789292e+12       0.618413      -0.100644
# 93551                     2.050680e+12       2.978121      -4.332648
# 25427                     1.418902e+12       1.645851      -2.828791
# 70609                     4.112754e+12       3.061698      -5.255691
#
#         RHi initial, Mean  Mean nvPM number EI (kg-1)  Tau contrail, Mean  \
# 22481            0.943972                5.265598e+14            0.076310
# 25986            1.137655                7.863917e+14            0.120179
# 81343            1.138143                1.640946e+15            0.204437
# 16215            1.063777                1.398712e+15            0.115274
# 2306             1.060152                5.817175e+14            0.126543
# ...                   ...                         ...                 ...
# 180743           0.926420                5.683954e+14            0.114692
# 44251            1.009517                1.138433e+15            0.033863
# 93551            1.033206                5.049383e+14            0.057980
# 25427            1.020880                5.443331e+14            0.029348
# 70609            1.065406                1.525287e+15            0.058219
#
#              y1_val    y2_val
# 22481    444.885080  0.013889
# 25986   1311.580512  3.375917
# 81343    471.953017  5.528770
# 16215    509.433198  2.742529
# 2306     717.196763  3.174537
# ...             ...       ...
# 180743   391.275454  0.019722
# 44251    942.394345  3.005570
# 93551   1152.773003  2.741430
# 25427     26.999373  1.059167
# 70609   1466.250298  1.574566
#
# [26708 rows x 12 columns]

# %%
test_data
# Out:
#         Ice vol mean radius, Mean (um)  Total contrail EF (J)  \
# 124207                        2.124384           2.081313e+10
# 65306                        12.060076           6.759228e+14
# 175617                        3.867689          -1.236160e+12
# 191692                        8.721138           3.023121e+14
# 123906                        7.376239           5.683026e+14
# ...                                ...                    ...
# 29112                         0.944434           1.465548e+09
# 186667                        2.377560          -3.377631e+12
# 68191                        14.001348           3.710885e+12
# 153533                        0.392513           0.000000e+00
# 88293                        16.732838           2.397133e+14
#
#         Temp initial, Mean (K)  Tau cirrus, Mean  \
# 124207              219.523399          0.058384
# 65306               216.279325          0.146637
# 175617              212.228943          0.083984
# 191692              216.666283          0.092748
# 123906              214.390667          0.044035
# ...                        ...               ...
# 29112               217.752149          0.091864
# 186667              216.905162          0.268586
# 68191               220.001920          0.248675
# 153533              211.443842          0.003407
# 88293               219.905092          0.113812
#
#         Ice number initial, Mean (m-1)  RF LW (W m-2)  RF SW (W m-2)  \
# 124207                    9.890413e+11       0.486495       0.000000
# 65306                     3.371385e+12       2.354377      -0.045600
# 175617                    2.294662e+12       1.446365      -2.298702
# 191692                    1.720397e+12       7.101081      -5.868207
# 123906                    4.548521e+12       4.799556      -0.292952
# ...                                ...            ...            ...
# 29112                     2.473524e+12       0.601529       0.000000
# 186667                    5.210830e+12       2.975541      -8.921281
# 68191                     2.921218e+12       2.950087      -2.259663
# 153533                    1.033830e+13       1.122697       0.000000
# 88293                     2.735267e+12       9.572269       0.000000
#
#         RHi initial, Mean  Mean nvPM number EI (kg-1)  Tau contrail, Mean  \
# 124207           0.985102                1.019419e+15            0.055399
# 65306            0.963492                5.360051e+14            0.109678
# 175617           1.012369                5.057628e+14            0.074585
# 191692           1.141068                2.061204e+14            0.136122
# 123906           1.077156                1.363225e+15            0.095912
# ...                   ...                         ...                 ...
# 29112            0.998493                1.295352e+15            0.059556
# 186667           0.884443                5.166632e+14            0.153192
# 68191            1.198047                6.705264e+14            0.180562
# 153533           0.688827                1.145583e+15            0.122743
# 88293            1.182552                5.248680e+14            0.158077
#
#             y1_test   y2_test
# 124207   241.065124  0.337857
# 65306   1286.319823  8.551167
# 175617   657.080019  1.660417
# 191692  2118.706136  4.246465
# 123906   770.560542  4.301790
# ...             ...       ...
# 29112    753.499178  0.041944
# 186667   308.770716  0.841667
# 68191     94.484589  4.704008
# 153533   582.539187  0.016667
# 88293    208.891963  3.365897
#
# [26708 rows x 12 columns]

# %% [markdown]
# # stop & resume below on part2 ----------------------------->
